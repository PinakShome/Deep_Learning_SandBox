# %% [markdown]
# <h1> Importing Libraries and Exploring Data

# %%
import pandas as pd
import numpy as np
import warnings
import nltk
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from wordcloud import WordCloud
import matplotlib.pyplot as plt
warnings.filterwarnings('ignore')
import sys

# %%
print(sys.executable)
# Out:
# /opt/anaconda3/bin/python

# %% [markdown]
# <h2> Input

# %%
#Reading in the files
df = pd.read_json('/Users/pinakshome/Downloads/pii-detection/train.json')

# %% [markdown]
# <h3> Pre-EDA

# %%
df.head()
# Out:
#    document                                          full_text  \
# 0         7  Design Thinking for innovation reflexion-Avril...
# 1        10  Diego Estrada\n\nDesign Thinking Assignment\n\...
# 2        16  Reporting process\n\nby Gilberto Gamboa\n\nCha...
# 3        20  Design Thinking for Innovation\n\nSindy Samaca...
# 4        56  Assignment:  Visualization Reflection  Submitt...
#
#                                               tokens  \
# 0  [Design, Thinking, for, innovation, reflexion,...
# 1  [Diego, Estrada, \n\n, Design, Thinking, Assig...
# 2  [Reporting, process, \n\n, by, Gilberto, Gambo...
# 3  [Design, Thinking, for, Innovation, \n\n, Sind...
# 4  [Assignment, :,   , Visualization,  , Reflecti...
#
#                                  trailing_whitespace  \
# 0  [True, True, True, True, False, False, True, F...
# 1  [True, False, False, True, True, False, False,...
# 2  [True, False, False, True, True, False, False,...
# 3  [True, True, True, False, False, True, False, ...
# 4  [False, False, False, False, False, False, Fal...
#
#                                               labels
# 0  [O, O, O, O, O, O, O, O, O, B-NAME_STUDENT, I-...
# 1  [B-NAME_STUDENT, I-NAME_STUDENT, O, O, O, O, O...
# 2  [O, O, O, O, B-NAME_STUDENT, I-NAME_STUDENT, O...
# 3  [O, O, O, O, O, B-NAME_STUDENT, I-NAME_STUDENT...
# 4  [O, O, O, O, O, O, O, O, O, O, O, O, B-NAME_ST...

# %%
df.shape
# Out:
# (6807, 5)

# %%
df.dtypes
# Out:
# document                int64
# full_text              object
# tokens                 object
# trailing_whitespace    object
# labels                 object
# dtype: object

# %%
(df['trailing_whitespace'][1][:5])
# Out:
# [True, False, False, True, True]

# %%
df['labels'][1][:5]
# Out:
# ['B-NAME_STUDENT', 'I-NAME_STUDENT', 'O', 'O', 'O']

# %%
len(df['tokens'][1])
# Out:
# 563

# %%
df['tokens'][1][:8]
# Out:
# ['Diego',
#  'Estrada',
#  '\n\n',
#  'Design',
#  'Thinking',
#  'Assignment',
#  '\n\n',
#  'Visualization']

# %%
len(df['full_text'])
# Out:
# 6807

# %%
len(df['full_text'][1])
# Out:
# 2915

# %% [markdown]
# <H3> EDA on full_text feature

# %% [markdown]
# <h3> Text Analysis

# %%
df['text_length'] = df['full_text'].apply(len)
plt.hist(df['text_length'], bins=10)
plt.xlabel('Text Length')
plt.ylabel('Frequency')
plt.title('Distribution of Text Length')
plt.show()

#Checking the distribution of text length

# %%
###Checking the top 20 words across all documents not considering stop words

stop_words = set(stopwords.words('english'))
all_words = [word for tokens in df['tokens'] for word in tokens if word.lower() not in stop_words]
word_freq = nltk.FreqDist(all_words)
word_freq.plot(20, title="Top 20 Words (excluding stopwords)")
# Out:
# <Axes: title={'center': 'Top 20 Words (excluding stopwords)'}, xlabel='Samples', ylabel='Counts'>

# %% [markdown]
# <h3> Tokens

# %%
df['token_count'] = df['tokens'].apply(len)
plt.hist(df['token_count'], bins=10)
plt.xlabel('Token Count')
plt.ylabel('Frequency')
plt.title('Distribution of Token Count')
plt.show()

# %%
unique_tokens = set(all_words)
print(f"Number of unique tokens: {len(unique_tokens)}")
# Out:
# Number of unique tokens: 53642

# %%
### Identifying if tokens are already standardized 

from collections import defaultdict


all_tokens = [token for sublist in df['tokens'] for token in sublist]

# Creating a dictionary to hold each unique token and its variations
token_variations = defaultdict(set)

# Populating the dictionary
for token in all_tokens:
    # Using a standardized form for matching 
    standardized_token = token.lower()
    token_variations[standardized_token].add(token)

# Identifying tokens with variations
count=0
for standard_token, variations in token_variations.items():
    count+=1
    if len(variations) > 1 and count<50:
        print(f"Token: {standard_token}, Variations: {variations}")
        
        
        
        
####### The tokens are not completely inconsistency free

## We will check further to see if we have punctuational token variations
# Out:
# Token: design, Variations: {'DESIGN', 'design', 'Design'}
# Token: thinking, Variations: {'Thinking', 'THINKING', 'thinking'}
# Token: for, Variations: {'for', 'FOR', 'For'}
# Token: innovation, Variations: {'INNOVATION', 'innovation', 'Innovation'}
# Token: reflexion, Variations: {'reflexion', 'Reflexion'}
# Token: challenge, Variations: {'challenge', 'CHALLENGE', 'Challenge'}
# Token: selection, Variations: {'Selection', 'selection', 'SELECTION'}
# Token: the, Variations: {'The', 'THE', 'the'}
# Token: tool, Variations: {'TOOL', 'Tool', 'tool', 'TooL'}
# Token: i, Variations: {'I', 'i'}
# Token: use, Variations: {'USE', 'use', 'Use'}
# Token: to, Variations: {'TO', 'To', 'to'}
# Token: help, Variations: {'help', 'Help', 'HELP'}
# Token: all, Variations: {'all', 'ALL', 'All'}
# Token: stakeholders, Variations: {'STAKEHOLDERS', 'stakeholders', 'Stakeholders'}
# Token: finding, Variations: {'finding', 'Finding'}
# Token: their, Variations: {'Their', 'THEIR', 'their'}
# Token: way, Variations: {'Way', 'WAY', 'way'}
# Token: through, Variations: {'through', 'Through', 'THROUGH'}
# Token: complexity, Variations: {'complexity', 'Complexity'}
# Token: of, Variations: {'oF', 'OF', 'Of', 'of'}
# Token: a, Variations: {'a', 'A'}
# Token: project, Variations: {'project', 'Project', 'PROJECT'}
# Token: is, Variations: {'Is', 'is', 'IS'}
# Token: mind, Variations: {'Mind', 'mInd', 'MIND', 'mind'}
# Token: map, Variations: {'MAP', 'Map', 'map'}
# Token: what, Variations: {'What', 'what', 'WHAT'}
# Token: exactly, Variations: {'exactly', 'Exactly'}
# Token: according, Variations: {'according', 'According'}
# Token: definition, Variations: {'DEFINITION', 'Definition', 'definition'}
# Token: buzan, Variations: {'Buzan', 'buzan'}
# Token: and, Variations: {'AND', 'and', 'And'}
# Token: b., Variations: {'B.', 'b.'}

# %%
import string
from collections import defaultdict


all_tokens = [token for sublist in df['tokens'] for token in sublist]

# Function to remove punctuation from a token
def remove_punctuation(text):
    return text.translate(str.maketrans('', '', string.punctuation))

# Dictionary to keep track of tokens with and without punctuation
tokens_with_without_punct = defaultdict(lambda: {'with': set(), 'without': set()})

for token in all_tokens:
    stripped_token = remove_punctuation(token)
    if stripped_token != token:
        # The token had punctuation and was modified
        tokens_with_without_punct[stripped_token]['with'].add(token)
    else:
        # The token had no punctuation to remove
        tokens_with_without_punct[stripped_token]['without'].add(token)

# Now, we'll find tokens that exist both with and without punctuation
tokens_with_both_forms = {token: forms for token, forms in tokens_with_without_punct.items() if forms['with'] and forms['without']}

# Display results
for token, forms in tokens_with_both_forms.items():
    print(f"Base Token: {token}, With Punctuation: {forms['with']}, Without Punctuation: {forms['without']}")
# Out:
# Base Token: Design, With Punctuation: {'Design--'}, Without Punctuation: {'Design'}
# Base Token: Thinking, With Punctuation: {'Thinking-'}, Without Punctuation: {'Thinking'}
# Base Token: for, With Punctuation: {'.for', 'for/', '-for'}, Without Punctuation: {'for'}
# Base Token: innovation, With Punctuation: {'innovation-', '-innovation'}, Without Punctuation: {'innovation'}
# Base Token: Challenge, With Punctuation: {'Challenge-', 'Challenge:-', '-Challenge-', 'Challenge/'}, Without Punctuation: {'Challenge'}
# Base Token: selection, With Punctuation: {'selection-'}, Without Punctuation: {'selection'}
# Base Token: The, With Punctuation: {'-The', 'The-', '.The'}, Without Punctuation: {'The'}
# Base Token: tool, With Punctuation: {'-tool', 'tool-'}, Without Punctuation: {'tool'}
# Base Token: I, With Punctuation: {'I.', '-I', '.I'}, Without Punctuation: {'I'}
# Base Token: use, With Punctuation: {'use-', 'use/'}, Without Punctuation: {'use'}
# Base Token: to, With Punctuation: {'to-'}, Without Punctuation: {'to'}
# Base Token: all, With Punctuation: {'all-', '-all'}, Without Punctuation: {'all'}
# Base Token: stakeholders, With Punctuation: {'stakeholders/', 'stakeholders-', 'stakeholder(s'}, Without Punctuation: {'stakeholders'}
# Base Token: way, With Punctuation: {'way-'}, Without Punctuation: {'way'}
# Base Token: the, With Punctuation: {'.the', '-the', '/the', 'the-'}, Without Punctuation: {'the'}
# Base Token: of, With Punctuation: {'of-'}, Without Punctuation: {'of'}
# Base Token: a, With Punctuation: {'-a', '/a', '.a', 'a.'}, Without Punctuation: {'a'}
# Base Token: project, With Punctuation: {'project/', 'project-'}, Without Punctuation: {'project'}
# Base Token: is, With Punctuation: {'is-', 'is:-'}, Without Punctuation: {'is'}
# Base Token: mind, With Punctuation: {'mind/', 'mind-'}, Without Punctuation: {'mind'}
# Base Token: map, With Punctuation: {'map-', 'map:-'}, Without Punctuation: {'map'}
# Base Token: What, With Punctuation: {'What-', '-What'}, Without Punctuation: {'What'}
# Base Token: T, With Punctuation: {'T-', 'T.'}, Without Punctuation: {'T'}
# Base Token: and, With Punctuation: {'-and', 'and/', '/and', 'and-', '.and'}, Without Punctuation: {'and'}
# Base Token: B, With Punctuation: {'B.', 'B-'}, Without Punctuation: {'B'}
# Base Token: or, With Punctuation: {'/or', 'or-'}, Without Punctuation: {'or'}
# Base Token: technique, With Punctuation: {'technique-'}, Without Punctuation: {'technique'}
# Base Token: that, With Punctuation: {'that-'}, Without Punctuation: {'that'}
# Base Token: follows, With Punctuation: {'follows-', 'follows:-'}, Without Punctuation: {'follows'}
# Base Token: s, With Punctuation: {'s.', "'s", '-s'}, Without Punctuation: {'s'}
# Base Token: potential, With Punctuation: {'potential-'}, Without Punctuation: {'potential'}
# Base Token: be, With Punctuation: {'be-'}, Without Punctuation: {'be'}
# Base Token: This, With Punctuation: {'.This'}, Without Punctuation: {'This'}
# Base Token: many, With Punctuation: {'many/', '.many'}, Without Punctuation: {'many'}
# Base Token: It, With Punctuation: {'-It', '.It'}, Without Punctuation: {'It'}
# Base Token: not, With Punctuation: {'-not', '.not'}, Without Punctuation: {'not'}
# Base Token: require, With Punctuation: {'require-', 'require/'}, Without Punctuation: {'require'}
# Base Token: done, With Punctuation: {'done-', '-done', 'done/'}, Without Punctuation: {'done'}
# Base Token: quickly, With Punctuation: {'quickly--'}, Without Punctuation: {'quickly'}
# Base Token: information, With Punctuation: {'information/', 'information-'}, Without Punctuation: {'information'}
# Base Token: situation, With Punctuation: {'situation/'}, Without Punctuation: {'situation'}
# Base Token: problem, With Punctuation: {'problem/', 'problem-'}, Without Punctuation: {'problem'}
# Base Token: solving, With Punctuation: {'solving-', '-solving'}, Without Punctuation: {'solving'}
# Base Token: new, With Punctuation: {'new-', '-new'}, Without Punctuation: {'new'}
# Base Token: ideas, With Punctuation: {'idea(s', 'ideas/'}, Without Punctuation: {'ideas'}
# Base Token: people, With Punctuation: {'people-', 'people/'}, Without Punctuation: {'people'}
# Base Token: easy, With Punctuation: {'easy-'}, Without Punctuation: {'easy'}
# Base Token: learn, With Punctuation: {'learn-'}, Without Punctuation: {'learn'}
# Base Token: projects, With Punctuation: {'projects/'}, Without Punctuation: {'projects'}
# Base Token: you, With Punctuation: {'.you', 'you?-'}, Without Punctuation: {'you'}
# Base Token: with, With Punctuation: {'-with', 'with/'}, Without Punctuation: {'with'}
# Base Token: an, With Punctuation: {'-an'}, Without Punctuation: {'an'}
# Base Token: idea, With Punctuation: {'idea/', 'idea-', '/idea'}, Without Punctuation: {'idea'}
# Base Token: at, With Punctuation: {'at-'}, Without Punctuation: {'at'}
# Base Token: its, With Punctuation: {'-its', "i'ts", 'it`s'}, Without Punctuation: {'its'}
# Base Token: center, With Punctuation: {'center/'}, Without Punctuation: {'center'}
# Base Token: point, With Punctuation: {'point/', '.point'}, Without Punctuation: {'point'}
# Base Token: work, With Punctuation: {'work/', 'work-'}, Without Punctuation: {'work'}
# Base Token: areas, With Punctuation: {'area(s', 'areas-'}, Without Punctuation: {'areas'}
# Base Token: this, With Punctuation: {'.this'}, Without Punctuation: {'this'}
# Base Token: in, With Punctuation: {'in/', 'in-', '-in', '.in'}, Without Punctuation: {'in'}
# Base Token: structure, With Punctuation: {'structure/'}, Without Punctuation: {'structure'}
# Base Token: which, With Punctuation: {'which-', '-which'}, Without Punctuation: {'which'}
# Base Token: as, With Punctuation: {'.as', 'as-', '-as'}, Without Punctuation: {'as'}
# Base Token: branches, With Punctuation: {'branches/'}, Without Punctuation: {'branches'}
# Base Token: creativity, With Punctuation: {'creativity-'}, Without Punctuation: {'creativity'}
# Base Token: it, With Punctuation: {'.it', 'it-'}, Without Punctuation: {'it'}
# Base Token: thoughts, With Punctuation: {'thoughts/'}, Without Punctuation: {'thoughts'}
# Base Token: because, With Punctuation: {'-because'}, Without Punctuation: {'because'}
# Base Token: participants, With Punctuation: {'participants/'}, Without Punctuation: {'participants'}
# Base Token: Application, With Punctuation: {'Application:-', ',Application', 'Application-', '-Application-'}, Without Punctuation: {'Application'}
# Base Token: Insight, With Punctuation: {'-Insight-', 'Insight:-', 'Insight-'}, Without Punctuation: {'Insight'}
# Base Token: start, With Punctuation: {'start-'}, Without Punctuation: {'start'}
# Base Token: process, With Punctuation: {'process/', 'process/.', 'process:-', 'process-'}, Without Punctuation: {'process'}
# Base Token: large, With Punctuation: {'large-'}, Without Punctuation: {'large'}
# Base Token: board, With Punctuation: {'board-'}, Without Punctuation: {'board'}
# Base Token: paper, With Punctuation: {'paper-'}, Without Punctuation: {'paper'}
# Base Token: In, With Punctuation: {'In-', '.In'}, Without Punctuation: {'In'}
# Base Token: design, With Punctuation: {'design-', 'design/'}, Without Punctuation: {'design'}
# Base Token: Through, With Punctuation: {'.Through'}, Without Punctuation: {'Through'}
# Base Token: questions, With Punctuation: {'questions-'}, Without Punctuation: {'questions'}
# Base Token: guide, With Punctuation: {'guide/'}, Without Punctuation: {'guide'}
# Base Token: according, With Punctuation: {'.according'}, Without Punctuation: {'according'}
# Base Token: we, With Punctuation: {',we', '.we', '/we'}, Without Punctuation: {'we'}
# Base Token: what, With Punctuation: {'.what', 'what-', ',what', '-what'}, Without Punctuation: {'what'}
# Base Token: when, With Punctuation: {'.when'}, Without Punctuation: {'when'}
# Base Token: where, With Punctuation: {'.where'}, Without Punctuation: {'where'}
# Base Token: how, With Punctuation: {',how'}, Without Punctuation: {'how'}
# Base Token: interesting, With Punctuation: {'interesting-', 'interesting/'}, Without Punctuation: {'interesting'}
# Base Token: understand, With Punctuation: {'understand/'}, Without Punctuation: {'understand'}
# Base Token: By, With Punctuation: {'.By', 'By-'}, Without Punctuation: {'By'}
# Base Token: person, With Punctuation: {'person-'}, Without Punctuation: {'person'}
# Base Token: from, With Punctuation: {'-from'}, Without Punctuation: {'from'}
# Base Token: ways, With Punctuation: {'way(s'}, Without Punctuation: {'ways'}
# Base Token: two, With Punctuation: {'two+', 'two-', '/two'}, Without Punctuation: {'two'}
# Base Token: hours, With Punctuation: {'hours/'}, Without Punctuation: {'hours'}
# Base Token: After, With Punctuation: {'.After', '/After'}, Without Punctuation: {'After'}
# Base Token: on, With Punctuation: {'on-'}, Without Punctuation: {'on'}
# Base Token: digital, With Punctuation: {'digital-'}, Without Punctuation: {'digital'}
# Base Token: visualization, With Punctuation: {'visualization-', '-visualization', 'visualization/'}, Without Punctuation: {'visualization'}
# Base Token: second, With Punctuation: {'second-'}, Without Punctuation: {'second'}
# Base Token: Once, With Punctuation: {'.Once'}, Without Punctuation: {'Once'}
# Base Token: power, With Punctuation: {'power-'}, Without Punctuation: {'power'}
# Base Token: Then, With Punctuation: {'.Then'}, Without Punctuation: {'Then'}
# Base Token: out, With Punctuation: {'out-'}, Without Punctuation: {'out'}
# Base Token: even, With Punctuation: {'-even'}, Without Punctuation: {'even'}
# Base Token: more, With Punctuation: {'more-'}, Without Punctuation: {'more'}
# Base Token: they, With Punctuation: {'.they'}, Without Punctuation: {'they'}
# Base Token: together, With Punctuation: {'together-'}, Without Punctuation: {'together'}
# Base Token: now, With Punctuation: {'now-'}, Without Punctuation: {'now'}
# Base Token: manage, With Punctuation: {'manage/'}, Without Punctuation: {'manage'}
# Base Token: understanding, With Punctuation: {'understanding-'}, Without Punctuation: {'understanding'}
# Base Token: decision, With Punctuation: {'decision-'}, Without Punctuation: {'decision'}
# Base Token: These, With Punctuation: {'-These', '.These'}, Without Punctuation: {'These'}
# Base Token: are, With Punctuation: {'are-', 'are:-'}, Without Punctuation: {'are'}
# Base Token: my, With Punctuation: {'-my', 'my/'}, Without Punctuation: {'my'}
# Base Token: business, With Punctuation: {'business/', 'business--'}, Without Punctuation: {'business'}
# Base Token: validate, With Punctuation: {'validate-'}, Without Punctuation: {'validate'}
# Base Token: them, With Punctuation: {'them-'}, Without Punctuation: {'them'}
# Base Token: They, With Punctuation: {'.They'}, Without Punctuation: {'They'}
# Base Token: Approach, With Punctuation: {'/Approach', 'Approach:-', 'Approach-', '-Approach'}, Without Punctuation: {'Approach'}
# Base Token: give, With Punctuation: {'give/'}, Without Punctuation: {'give'}
# Base Token: story, With Punctuation: {'.story', 'story-', '-story'}, Without Punctuation: {'story'}
# Base Token: A, With Punctuation: {'A-', '.A', '-A', 'A.'}, Without Punctuation: {'A'}
# Base Token: 1, With Punctuation: {'1/', '1-', '-1', '"1', ':1', '1.-', '-1-', '1|'}, Without Punctuation: {'1'}
# Base Token: Mind, With Punctuation: {'-Mind', 'Mind-', '.Mind'}, Without Punctuation: {'Mind'}
# Base Token: Map, With Punctuation: {'Map-'}, Without Punctuation: {'Map'}
# Base Token: Assignment, With Punctuation: {'Assignment-', 'Assignment/'}, Without Punctuation: {'Assignment'}
# Base Token: Visualization, With Punctuation: {'-Visualization', '.Visualization', 'Visualization-'}, Without Punctuation: {'Visualization'}
# Base Token: Tool, With Punctuation: {'Tool-'}, Without Punctuation: {'Tool'}
# Base Token: Selection, With Punctuation: {'Selection-', 'Selection:-', '-Selection-'}, Without Punctuation: {'Selection'}
# Base Token: were, With Punctuation: {'were-'}, Without Punctuation: {'were'}
# Base Token: hard, With Punctuation: {'hard-'}, Without Punctuation: {'hard'}
# Base Token: time, With Punctuation: {'time/', '-time', 'time-'}, Without Punctuation: {'time'}
# Base Token: changes, With Punctuation: {'changes-'}, Without Punctuation: {'changes'}
# Base Token: As, With Punctuation: {'.As', 'As-'}, Without Punctuation: {'As'}
# Base Token: solution, With Punctuation: {'solution/', 'solution-'}, Without Punctuation: {'solution'}
# Base Token: customer, With Punctuation: {'customer/', 'customer-'}, Without Punctuation: {'customer'}
# Base Token: approach, With Punctuation: {'/approach', 'approach-', 'approach:-', 'approach/'}, Without Punctuation: {'approach'}
# Base Token: was, With Punctuation: {'was-'}, Without Punctuation: {'was'}
# Base Token: needed, With Punctuation: {'needed-'}, Without Punctuation: {'needed'}
# Base Token: learning, With Punctuation: {'learning/'}, Without Punctuation: {'learning'}
# Base Token: thinking, With Punctuation: {'thinking/', 'thinking-'}, Without Punctuation: {'thinking'}
# Base Token: course, With Punctuation: {'course/'}, Without Punctuation: {'course'}
# Base Token: team, With Punctuation: {'team-'}, Without Punctuation: {'team'}
# Base Token: create, With Punctuation: {'create/'}, Without Punctuation: {'create'}
# Base Token: presentation, With Punctuation: {'-presentation'}, Without Punctuation: {'presentation'}
# Base Token: using, With Punctuation: {'-using'}, Without Punctuation: {'using'}
# Base Token: drawings, With Punctuation: {'drawings/', '/drawings'}, Without Punctuation: {'drawings'}
# Base Token: go, With Punctuation: {'go-'}, Without Punctuation: {'go'}
# Base Token: Previous, With Punctuation: {'Previous-'}, Without Punctuation: {'Previous'}
# Base Token: change, With Punctuation: {'change-'}, Without Punctuation: {'change'}
# Base Token: solutions, With Punctuation: {'solutions/', 'solution(s'}, Without Punctuation: {'solutions'}
# Base Token: but, With Punctuation: {'.but'}, Without Punctuation: {'but'}
# Base Token: connection, With Punctuation: {'connection-'}, Without Punctuation: {'connection'}
# Base Token: did, With Punctuation: {'did/'}, Without Punctuation: {'did'}
# Base Token: uses, With Punctuation: {'uses:-'}, Without Punctuation: {'uses'}
# Base Token: tools, With Punctuation: {'tools/', 'tools-', 'tools:-', 'tool(s'}, Without Punctuation: {'tools'}
# Base Token: software, With Punctuation: {'/software'}, Without Punctuation: {'software'}
# Base Token: develop, With Punctuation: {'develop/'}, Without Punctuation: {'develop'}
# Base Token: surveys, With Punctuation: {'/surveys'}, Without Punctuation: {'surveys'}
# Base Token: gathered, With Punctuation: {'gathered-'}, Without Punctuation: {'gathered'}
# Base Token: research, With Punctuation: {'research-', '-research'}, Without Punctuation: {'research'}
# Base Token: show, With Punctuation: {'show-'}, Without Punctuation: {'show'}
# Base Token: statistics, With Punctuation: {'/statistics'}, Without Punctuation: {'statistics'}
# Base Token: visual, With Punctuation: {'visual-', '-visual'}, Without Punctuation: {'visual'}
# Base Token: game, With Punctuation: {'game-', 'game/'}, Without Punctuation: {'game'}
# Base Token: hands, With Punctuation: {'hands-'}, Without Punctuation: {'hands'}
# Base Token: activity, With Punctuation: {'activity-', 'activity:-', 'activity/'}, Without Punctuation: {'activity'}
# Base Token: need, With Punctuation: {'need-', 'need/'}, Without Punctuation: {'need'}
# Base Token: impact, With Punctuation: {'/impact'}, Without Punctuation: {'impact'}
# Base Token: group, With Punctuation: {'group-'}, Without Punctuation: {'group'}
# Base Token: company, With Punctuation: {'company-'}, Without Punctuation: {'company'}
# Base Token: like, With Punctuation: {'-like', 'like-', 'like/', '.like'}, Without Punctuation: {'like'}
# Base Token: part, With Punctuation: {'part/', 'part-'}, Without Punctuation: {'part'}
# Base Token: problems, With Punctuation: {'problems/', 'problems-', 'problem(s'}, Without Punctuation: {'problems'}
# Base Token: well, With Punctuation: {'well-', 'we`ll', '-well', 'well/'}, Without Punctuation: {'well'}
# Base Token: Every, With Punctuation: {'.Every'}, Without Punctuation: {'Every'}
# Base Token: customers, With Punctuation: {'/customers', 'customer(s', 'customers.-', '-customers', 'customers/', 'customers-'}, Without Punctuation: {'customers'}
# Base Token: do, With Punctuation: {'do-'}, Without Punctuation: {'do'}
# Base Token: page, With Punctuation: {'page/'}, Without Punctuation: {'page'}
# Base Token: better, With Punctuation: {'better-'}, Without Punctuation: {'better'}
# Base Token: Team, With Punctuation: {'Team-'}, Without Punctuation: {'Team'}
# Base Token: success, With Punctuation: {'success-'}, Without Punctuation: {'success'}
# Base Token: rate, With Punctuation: {'rate/'}, Without Punctuation: {'rate'}
# Base Token: based, With Punctuation: {'-based'}, Without Punctuation: {'based'}
# Base Token: activities, With Punctuation: {'activities-', 'activities/'}, Without Punctuation: {'activities'}
# Base Token: increase, With Punctuation: {'increase-'}, Without Punctuation: {'increase'}
# Base Token: learnt, With Punctuation: {'/learnt'}, Without Punctuation: {'learnt'}
# Base Token: difficult, With Punctuation: {'difficult/'}, Without Punctuation: {'difficult'}
# Base Token: things, With Punctuation: {'things-'}, Without Punctuation: {'things'}
# Base Token: just, With Punctuation: {'-just'}, Without Punctuation: {'just'}
# Base Token: flow, With Punctuation: {'flow/'}, Without Punctuation: {'flow'}
# Base Token: by, With Punctuation: {'.by', 'by-', '-by', 'by:-'}, Without Punctuation: {'by'}
# Base Token: CFO, With Punctuation: {'C.F.O.'}, Without Punctuation: {'CFO'}
# Base Token: weekly, With Punctuation: {'weekly/'}, Without Punctuation: {'weekly'}
# Base Token: report, With Punctuation: {'-report'}, Without Punctuation: {'report'}
# Base Token: results, With Punctuation: {'results/', 'results-'}, Without Punctuation: {'results'}
# Base Token: month, With Punctuation: {'month-'}, Without Punctuation: {'month'}
# Base Token: 4, With Punctuation: {'4/', '4-', '-4-', '+4', '-4', '~4', '4.-'}, Without Punctuation: {'4'}
# Base Token: When, With Punctuation: {'.When'}, Without Punctuation: {'When'}
# Base Token: CEO, With Punctuation: {'C.E.O'}, Without Punctuation: {'CEO'}
# Base Token: interest, With Punctuation: {'interest-'}, Without Punctuation: {'interest'}
# Base Token: him, With Punctuation: {'him/', 'him-'}, Without Punctuation: {'him'}
# Base Token: he, With Punctuation: {'he/'}, Without Punctuation: {'he'}
# Base Token: his, With Punctuation: {'his/'}, Without Punctuation: {'his'}
# Base Token: took, With Punctuation: {'-took'}, Without Punctuation: {'took'}
# Base Token: full, With Punctuation: {'full-'}, Without Punctuation: {'full'}
# Base Token: day, With Punctuation: {'day-', '-day'}, Without Punctuation: {'day'}
# Base Token: attention, With Punctuation: {'attention-'}, Without Punctuation: {'attention'}
# Base Token: reduce, With Punctuation: {'reduce/'}, Without Punctuation: {'reduce'}
# Base Token: human, With Punctuation: {'human-'}, Without Punctuation: {'human'}
# Base Token: directly, With Punctuation: {'directly/'}, Without Punctuation: {'directly'}
# Base Token: file, With Punctuation: {'file]/'}, Without Punctuation: {'file'}
# Base Token: there, With Punctuation: {'there-', '.there', '-there'}, Without Punctuation: {'there'}
# Base Token: kind, With Punctuation: {'-kind'}, Without Punctuation: {'kind'}
# Base Token: users, With Punctuation: {'users-', 'users/'}, Without Punctuation: {'users'}
# Base Token: some, With Punctuation: {'some-'}, Without Punctuation: {'some'}
# Base Token: reading, With Punctuation: {'reading/', 'reading----------'}, Without Punctuation: {'reading'}
# Base Token: IT, With Punctuation: {'I.T.', 'IT/', 'I.T', '-IT', 'IT-', '/IT'}, Without Punctuation: {'IT'}
# Base Token: best, With Punctuation: {'best-'}, Without Punctuation: {'best'}
# Base Token: For, With Punctuation: {'.For'}, Without Punctuation: {'For'}
# Base Token: first, With Punctuation: {'.first', 'first-'}, Without Punctuation: {'first'}
# Base Token: processes, With Punctuation: {'processes-', 'processes/'}, Without Punctuation: {'processes'}
# Base Token: so, With Punctuation: {'--so', '.so', 'so-'}, Without Punctuation: {'so'}
# Base Token: application, With Punctuation: {'application-', 'application/'}, Without Punctuation: {'application'}
# Base Token: comments, With Punctuation: {'comments/'}, Without Punctuation: {'comments'}
# Base Token: one, With Punctuation: {'one-'}, Without Punctuation: {'one'}
# Base Token: after, With Punctuation: {'.after'}, Without Punctuation: {'after'}
# Base Token: meeting, With Punctuation: {'meeting/', 'meeting-'}, Without Punctuation: {'meeting'}
# Base Token: post, With Punctuation: {'post-'}, Without Punctuation: {'post'}
# Base Token: review, With Punctuation: {'review/'}, Without Punctuation: {'review'}
# Base Token: provided, With Punctuation: {'provided-'}, Without Punctuation: {'provided'}
# Base Token: feedback, With Punctuation: {'feedback/'}, Without Punctuation: {'feedback'}
# Base Token: 36, With Punctuation: {'3.6', '.36'}, Without Punctuation: {'36'}
# Base Token: 8, With Punctuation: {'8-', '8)'}, Without Punctuation: {'8'}
# Base Token: including, With Punctuation: {'-including', '--including'}, Without Punctuation: {'including'}
# Base Token: data, With Punctuation: {'data/', 'data-'}, Without Punctuation: {'data'}
# Base Token: With, With Punctuation: {'.With'}, Without Punctuation: {'With'}
# Base Token: launch, With Punctuation: {'launch-', 'launch/'}, Without Punctuation: {'launch'}
# Base Token: assumptions, With Punctuation: {'assumptions-', 'assumption(s'}, Without Punctuation: {'assumptions'}
# Base Token: test, With Punctuation: {'test/'}, Without Punctuation: {'test'}
# Base Token: these, With Punctuation: {'.these', 'the(se'}, Without Punctuation: {'these'}
# Base Token: On, With Punctuation: {'On-'}, Without Punctuation: {'On'}
# Base Token: hand, With Punctuation: {'-hand', 'hand-'}, Without Punctuation: {'hand'}
# Base Token: requirements, With Punctuation: {'requirement(s', 'requirements/'}, Without Punctuation: {'requirements'}
# Base Token: used, With Punctuation: {'used)-', 'used-'}, Without Punctuation: {'used'}
# Base Token: needs, With Punctuation: {'needs/', 'needs-'}, Without Punctuation: {'needs'}
# Base Token: insight, With Punctuation: {'insight-', 'in.sight'}, Without Punctuation: {'insight'}
# Base Token: launches, With Punctuation: {'launches/'}, Without Punctuation: {'launches'}
# Base Token: ones, With Punctuation: {'one(s', 'one`s'}, Without Punctuation: {'ones'}
# Base Token: future, With Punctuation: {'future/'}, Without Punctuation: {'future'}
# Base Token: designs, With Punctuation: {'designs/'}, Without Punctuation: {'designs'}
# Base Token: automation, With Punctuation: {'automation/'}, Without Punctuation: {'automation'}
# Base Token: reports, With Punctuation: {'reports/'}, Without Punctuation: {'reports'}
# Base Token: Innovation, With Punctuation: {'Innovation-', 'Innovation/', '-Innovation'}, Without Punctuation: {'Innovation'}
# Base Token: My, With Punctuation: {'.My'}, Without Punctuation: {'My'}
# Base Token: challenge, With Punctuation: {'challenge/', 'challenge:-', 'challenge-'}, Without Punctuation: {'challenge'}
# Base Token: demand, With Punctuation: {'demand/'}, Without Punctuation: {'demand'}
# Base Token: investor, With Punctuation: {'investor/'}, Without Punctuation: {'investor'}
# Base Token: product, With Punctuation: {'product-', 'product/'}, Without Punctuation: {'product'}
# Base Token: good, With Punctuation: {'good-'}, Without Punctuation: {'good'}
# Base Token: 50, With Punctuation: {'~50', '-50', '.50', '50-'}, Without Punctuation: {'50'}
# Base Token: focus, With Punctuation: {'focus/'}, Without Punctuation: {'focus'}
# Base Token: products, With Punctuation: {'product(s', 'products/'}, Without Punctuation: {'products'}
# Base Token: 20, With Punctuation: {'+20', '2.0', '20-', '/-20', '~20', '-20'}, Without Punctuation: {'20'}
# Base Token: stake, With Punctuation: {'stake-'}, Without Punctuation: {'stake'}
# Base Token: define, With Punctuation: {'define/'}, Without Punctuation: {'define'}
# Base Token: state, With Punctuation: {'state-'}, Without Punctuation: {'state'}
# Base Token: wide, With Punctuation: {'wide-'}, Without Punctuation: {'wide'}
# Base Token: study, With Punctuation: {'study/'}, Without Punctuation: {'study'}
# Base Token: clients, With Punctuation: {'client(s', 'clients-', 'client`s'}, Without Punctuation: {'clients'}
# Base Token: follow, With Punctuation: {'follow-'}, Without Punctuation: {'follow'}
# Base Token: up, With Punctuation: {'up-'}, Without Punctuation: {'up'}
# Base Token: supply, With Punctuation: {'supply-'}, Without Punctuation: {'supply'}
# Base Token: Which, With Punctuation: {'.Which'}, Without Punctuation: {'Which'}
# Base Token: production, With Punctuation: {'production/'}, Without Punctuation: {'production'}
# Base Token: steps, With Punctuation: {'steps:-'}, Without Punctuation: {'steps'}
# Base Token: thought, With Punctuation: {'thought-'}, Without Punctuation: {'thought'}
# Base Token: reality, With Punctuation: {'reality-', 'reality/'}, Without Punctuation: {'reality'}
# Base Token: side, With Punctuation: {'-side', 'side-'}, Without Punctuation: {'side'}
# Base Token: low, With Punctuation: {'low-'}, Without Punctuation: {'low'}
# Base Token: Thanks, With Punctuation: {'----------Thanks'}, Without Punctuation: {'Thanks'}
# Base Token: each, With Punctuation: {',each', 'each-'}, Without Punctuation: {'each'}
# Base Token: made, With Punctuation: {'-made'}, Without Punctuation: {'made'}
# Base Token: chose, With Punctuation: {'/chose'}, Without Punctuation: {'chose'}
# Base Token: lesson, With Punctuation: {'lesson/'}, Without Punctuation: {'lesson'}
# Base Token: must, With Punctuation: {'must-'}, Without Punctuation: {'must'}
# Base Token: cause, With Punctuation: {'cause/', 'cause-'}, Without Punctuation: {'cause'}
# Base Token: fits, With Punctuation: {'fits-'}, Without Punctuation: {'fits'}
# Base Token: knowledge, With Punctuation: {'knowledge/', 'knowledge-'}, Without Punctuation: {'knowledge'}
# Base Token: differently, With Punctuation: {'differently-'}, Without Punctuation: {'differently'}
# Base Token: creating, With Punctuation: {'.creating'}, Without Punctuation: {'creating'}
# Base Token: Reflection, With Punctuation: {'Reflection-', '-Reflection', 'Reflection.-'}, Without Punctuation: {'Reflection'}
# Base Token: To, With Punctuation: {'-To', 'To-'}, Without Punctuation: {'To'}
# Base Token: environmental, With Punctuation: {'environmental-'}, Without Punctuation: {'environmental'}
# Base Token: campaign, With Punctuation: {'campaign/', 'campaign-'}, Without Punctuation: {'campaign'}
# Base Token: piece, With Punctuation: {'/piece'}, Without Punctuation: {'piece'}
# Base Token: gift, With Punctuation: {'gift/'}, Without Punctuation: {'gift'}
# Base Token: Even, With Punctuation: {'.Even'}, Without Punctuation: {'Even'}
# Base Token: community, With Punctuation: {'community-'}, Without Punctuation: {'community'}
# Base Token: If, With Punctuation: {'If/', '.If'}, Without Punctuation: {'If'}
# Base Token: if, With Punctuation: {'.if'}, Without Punctuation: {'if'}
# Base Token: testing, With Punctuation: {'testing/'}, Without Punctuation: {'testing'}
# Base Token: cost, With Punctuation: {'cost/', 'cost-'}, Without Punctuation: {'cost'}
# Base Token: firm, With Punctuation: {'firm-'}, Without Punctuation: {'firm'}
# Base Token: concept, With Punctuation: {'/concept'}, Without Punctuation: {'concept'}
# Base Token: budget, With Punctuation: {'budget.-'}, Without Punctuation: {'budget'}
# Base Token: We, With Punctuation: {'.We', '-We'}, Without Punctuation: {'We'}
# Base Token: heart, With Punctuation: {'heart-'}, Without Punctuation: {'heart'}
# Base Token: criteria, With Punctuation: {'criteria/'}, Without Punctuation: {'criteria'}
# Base Token: four, With Punctuation: {'four-'}, Without Punctuation: {'four'}
# Base Token: pages, With Punctuation: {'pages-'}, Without Punctuation: {'pages'}
# Base Token: us, With Punctuation: {'us-'}, Without Punctuation: {'us'}
# Base Token: list, With Punctuation: {'list/'}, Without Punctuation: {'list'}
# Base Token: often, With Punctuation: {'often-', 'often/'}, Without Punctuation: {'often'}
# Base Token: discussions, With Punctuation: {'discussions"'}, Without Punctuation: {'discussions'}
# Base Token: goal, With Punctuation: {'goal-'}, Without Punctuation: {'goal'}
# Base Token: 25, With Punctuation: {'2.5', '25-', '~25', '2,5'}, Without Punctuation: {'25'}
# Base Token: 24, With Punctuation: {'2.4'}, Without Punctuation: {'24'}
# Base Token: three, With Punctuation: {'three-'}, Without Punctuation: {'three'}
# Base Token: fail, With Punctuation: {'fail/', 'fail-'}, Without Punctuation: {'fail'}
# Base Token: ideal, With Punctuation: {'ideal-'}, Without Punctuation: {'ideal'}
# Base Token: complex, With Punctuation: {'complex/'}, Without Punctuation: {'complex'}
# Base Token: issues, With Punctuation: {'issue(s'}, Without Punctuation: {'issues'}
# Base Token: daily, With Punctuation: {'daily/'}, Without Punctuation: {'daily'}
# Base Token: Time, With Punctuation: {'Time-'}, Without Punctuation: {'Time'}
# Base Token: However, With Punctuation: {'.However'}, Without Punctuation: {'However'}
# Base Token: journey, With Punctuation: {'journey?)/'}, Without Punctuation: {'journey'}
# Base Token: benefits, With Punctuation: {'/benefits'}, Without Punctuation: {'benefits'}
# Base Token: mapping, With Punctuation: {'mapping/', 'mapping-', '-mapping'}, Without Punctuation: {'mapping'}
# Base Token: storytelling, With Punctuation: {'-storytelling-', 'storytelling-', 'storytelling:-', '-storytelling'}, Without Punctuation: {'storytelling'}
# Base Token: short, With Punctuation: {'-short', 'short-'}, Without Punctuation: {'short'}
# Base Token: video, With Punctuation: {'video/'}, Without Punctuation: {'video'}
# Base Token: her, With Punctuation: {'/her', 'her/'}, Without Punctuation: {'her'}
# Base Token: perspective, With Punctuation: {'perspective-'}, Without Punctuation: {'perspective'}
# Base Token: interview, With Punctuation: {'interview-'}, Without Punctuation: {'interview'}
# Base Token: micro, With Punctuation: {'micro-'}, Without Punctuation: {'micro'}
# Base Token: Learning, With Punctuation: {'-Learning', '----Learning'}, Without Punctuation: {'Learning'}
# Base Token: Launch, With Punctuation: {'Launch-'}, Without Punctuation: {'Launch'}
# Base Token: high, With Punctuation: {'high-'}, Without Punctuation: {'high'}
# Base Token: quality, With Punctuation: {'quality/'}, Without Punctuation: {'quality'}
# Base Token: organic, With Punctuation: {'/organic'}, Without Punctuation: {'organic'}
# Base Token: cuisine, With Punctuation: {'cuisine/'}, Without Punctuation: {'cuisine'}
# Base Token: restaurants, With Punctuation: {'restaurants/'}, Without Punctuation: {'restaurants'}
# Base Token: 60, With Punctuation: {'60-', '~60', '-60'}, Without Punctuation: {'60'}
# Base Token: 35, With Punctuation: {'3,5', '3.5'}, Without Punctuation: {'35'}
# Base Token: 5, With Punctuation: {'5.-', '-5', '5-', '-5-', '~5'}, Without Punctuation: {'5'}
# Base Token: individuals, With Punctuation: {'individual(s'}, Without Punctuation: {'individuals'}
# Base Token: family, With Punctuation: {'family-'}, Without Punctuation: {'family'}
# Base Token: store, With Punctuation: {'store-'}, Without Punctuation: {'store'}
# Base Token: target, With Punctuation: {'target/'}, Without Punctuation: {'target'}
# Base Token: most, With Punctuation: {'most-', '-most'}, Without Punctuation: {'most'}
# Base Token: level, With Punctuation: {'level/'}, Without Punctuation: {'level'}
# Base Token: boxes, With Punctuation: {'boxes-'}, Without Punctuation: {'boxes'}
# Base Token: offer, With Punctuation: {'offer/'}, Without Punctuation: {'offer'}
# Base Token: lower, With Punctuation: {'lower-'}, Without Punctuation: {'lower'}
# Base Token: 75, With Punctuation: {'7.5', '~75'}, Without Punctuation: {'75'}
# Base Token: 15, With Punctuation: {'~15', '15-', '-15', '1.5', '1,5'}, Without Punctuation: {'15'}
# Base Token: food, With Punctuation: {'food-'}, Without Punctuation: {'food'}
# Base Token: Our, With Punctuation: {'.Our'}, Without Punctuation: {'Our'}
# Base Token: open, With Punctuation: {'open-'}, Without Punctuation: {'open'}
# Base Token: client, With Punctuation: {'client-', 'client/'}, Without Punctuation: {'client'}
# Base Token: Now, With Punctuation: {'.Now'}, Without Punctuation: {'Now'}
# Base Token: There, With Punctuation: {'.There', 'There-'}, Without Punctuation: {'There'}
# Base Token: Storytelling, With Punctuation: {'-_Storytelling', '-Storytelling', 'Storytelling-', '.Storytelling'}, Without Punctuation: {'Storytelling'}
# Base Token: audience, With Punctuation: {'audience-', 'audience/'}, Without Punctuation: {'audience'}
# Base Token: emotions, With Punctuation: {'emotions-', 'emotions/'}, Without Punctuation: {'emotions'}
# Base Token: empathy, With Punctuation: {'empathy-'}, Without Punctuation: {'empathy'}
# Base Token: Many, With Punctuation: {'.Many'}, Without Punctuation: {'Many'}
# Base Token: stories, With Punctuation: {'stories/', 'stories-', '.stories'}, Without Punctuation: {'stories'}
# Base Token: elements, With Punctuation: {'element(s'}, Without Punctuation: {'elements'}
# Base Token: get, With Punctuation: {'get-'}, Without Punctuation: {'get'}
# Base Token: Dr, With Punctuation: {'Dr.'}, Without Punctuation: {'Dr'}
# Base Token: organization, With Punctuation: {'organization-'}, Without Punctuation: {'organization'}
# Base Token: experience, With Punctuation: {'experience/'}, Without Punctuation: {'experience'}
# Base Token: scenarios, With Punctuation: {'scenario(s'}, Without Punctuation: {'scenarios'}
# Base Token: front, With Punctuation: {'front-'}, Without Punctuation: {'front'}
# Base Token: members, With Punctuation: {'members/', 'member(s'}, Without Punctuation: {'members'}
# Base Token: allow, With Punctuation: {'allow-'}, Without Punctuation: {'allow'}
# Base Token: insights, With Punctuation: {'insights-', 'insights/'}, Without Punctuation: {'insights'}
# Base Token: characters, With Punctuation: {'character(s'}, Without Punctuation: {'characters'}
# Base Token: real, With Punctuation: {'real-'}, Without Punctuation: {'real'}
# Base Token: ie, With Punctuation: {'i.e', 'i.e./', 'i.e.'}, Without Punctuation: {'ie'}
# Base Token: etc, With Punctuation: {'etc.-', 'e.t.c', 'et.c', '.etc', '----etc', 'etc-'}, Without Punctuation: {'etc'}
# Base Token: brand, With Punctuation: {'brand-'}, Without Punctuation: {'brand'}
# Base Token: market, With Punctuation: {'market-', 'market/'}, Without Punctuation: {'market'}
# Base Token: events, With Punctuation: {'events-', 'events/', '/events'}, Without Punctuation: {'events'}
# Base Token: number, With Punctuation: {'/number'}, Without Punctuation: {'number'}
# Base Token: student, With Punctuation: {'student-'}, Without Punctuation: {'student'}
# Base Token: inspiring, With Punctuation: {'inspiring-'}, Without Punctuation: {'inspiring'}
# Base Token: social, With Punctuation: {'-social'}, Without Punctuation: {'social'}
# Base Token: Community, With Punctuation: {'Community/'}, Without Punctuation: {'Community'}
# Base Token: suburbs, With Punctuation: {'suburbs/'}, Without Punctuation: {'suburbs'}
# Base Token: SP, With Punctuation: {'S&P'}, Without Punctuation: {'SP'}
# Base Token: improve, With Punctuation: {'imp[rove'}, Without Punctuation: {'improve'}
# Base Token: life, With Punctuation: {'life-'}, Without Punctuation: {'life'}
# Base Token: selling, With Punctuation: {'selling-'}, Without Punctuation: {'selling'}
# Base Token: Therefore, With Punctuation: {'.Therefore'}, Without Punctuation: {'Therefore'}
# Base Token: model, With Punctuation: {'model-', 'model='}, Without Punctuation: {'model'}
# Base Token: sustainable, With Punctuation: {'sustainable/'}, Without Punctuation: {'sustainable'}
# Base Token: door, With Punctuation: {'door-'}, Without Punctuation: {'door'}
# Base Token: action, With Punctuation: {'action/'}, Without Punctuation: {'action'}
# Base Token: So, With Punctuation: {'.So', '-So'}, Without Punctuation: {'So'}
# Base Token: Its, With Punctuation: {'It`s', '.Its'}, Without Punctuation: {'Its'}
# Base Token: examples, With Punctuation: {'examples-'}, Without Punctuation: {'examples'}
# Base Token: works, With Punctuation: {'works-'}, Without Punctuation: {'works'}
# Base Token: weeks, With Punctuation: {'weeks/'}, Without Punctuation: {'weeks'}
# Base Token: app, With Punctuation: {'app-'}, Without Punctuation: {'app'}
# Base Token: feed, With Punctuation: {'feed-'}, Without Punctuation: {'feed'}
# Base Token: zero, With Punctuation: {'zero-'}, Without Punctuation: {'zero'}
# Base Token: Insights, With Punctuation: {'Insights-', 'Insights:-', '/Insights'}, Without Punctuation: {'Insights'}
# Base Token: Testing, With Punctuation: {'-Testing'}, Without Punctuation: {'Testing'}
# Base Token: scenario, With Punctuation: {'scenario-'}, Without Punctuation: {'scenario'}
# Base Token: management, With Punctuation: {'management-'}, Without Punctuation: {'management'}
# Base Token: Technology, With Punctuation: {'Technology-'}, Without Punctuation: {'Technology'}
# Base Token: Management, With Punctuation: {'Management-'}, Without Punctuation: {'Management'}
# Base Token: 7, With Punctuation: {'.7', '7-'}, Without Punctuation: {'7'}
# Base Token: Why, With Punctuation: {'-Why'}, Without Punctuation: {'Why'}
# Base Token: sometimes, With Punctuation: {'.sometimes'}, Without Punctuation: {'sometimes'}
# Base Token: April, With Punctuation: {'April-'}, Without Punctuation: {'April'}
# Base Token: books, With Punctuation: {'books/'}, Without Punctuation: {'books'}
# Base Token: self, With Punctuation: {'self-'}, Without Punctuation: {'self'}
# Base Token: face, With Punctuation: {'face-'}, Without Punctuation: {'face'}
# Base Token: others, With Punctuation: {'others-'}, Without Punctuation: {'others'}
# Base Token: But, With Punctuation: {'.But'}, Without Punctuation: {'But'}
# Base Token: teaching, With Punctuation: {'teaching/'}, Without Punctuation: {'teaching'}
# Base Token: man, With Punctuation: {'man-'}, Without Punctuation: {'man'}
# Base Token: individual, With Punctuation: {'individual-'}, Without Punctuation: {'individual'}
# Base Token: All, With Punctuation: {'.All'}, Without Punctuation: {'All'}
# Base Token: resources, With Punctuation: {'resources-'}, Without Punctuation: {'resources'}
# Base Token: word, With Punctuation: {'word-', 'word/'}, Without Punctuation: {'word'}
# Base Token: let, With Punctuation: {'.let'}, Without Punctuation: {'let'}
# Base Token: besides, With Punctuation: {'-besides'}, Without Punctuation: {'besides'}
# Base Token: One, With Punctuation: {'-One', '.One'}, Without Punctuation: {'One'}
# Base Token: back, With Punctuation: {'back-'}, Without Punctuation: {'back'}
# Base Token: mean, With Punctuation: {'mean-'}, Without Punctuation: {'mean'}
# Base Token: People, With Punctuation: {'.People', '-People'}, Without Punctuation: {'People'}
# Base Token: b, With Punctuation: {'b.'}, Without Punctuation: {'b'}
# Base Token: free, With Punctuation: {'free-'}, Without Punctuation: {'free'}
# Base Token: x, With Punctuation: {'x%', 'x.', 'x-', '-x'}, Without Punctuation: {'x'}
# Base Token: y, With Punctuation: {'y.'}, Without Punctuation: {'y'}
# Base Token: share, With Punctuation: {'share/', 'share-'}, Without Punctuation: {'share'}
# Base Token: And, With Punctuation: {'.And'}, Without Punctuation: {'And'}
# Base Token: 30, With Punctuation: {'30-', '3.0', '30%)+', '~30', '-30', '/-30'}, Without Punctuation: {'30'}
# Base Token: students, With Punctuation: {'student(s'}, Without Punctuation: {'students'}
# Base Token: 2, With Punctuation: {'2/', '2-', '2)-', '-2', '.2', '2.-', '-2-'}, Without Punctuation: {'2'}
# Base Token: cases, With Punctuation: {'cases-', 'cases/'}, Without Punctuation: {'cases'}
# Base Token: end, With Punctuation: {'end-'}, Without Punctuation: {'end'}
# Base Token: games, With Punctuation: {'games/'}, Without Punctuation: {'games'}
# Base Token: she, With Punctuation: {'s)he', '/she'}, Without Punctuation: {'she'}
# Base Token: 13, With Punctuation: {'~13', '1/3', '1.3'}, Without Punctuation: {'13'}
# Base Token: fair, With Punctuation: {'fair-'}, Without Punctuation: {'fair'}
# Base Token: example, With Punctuation: {'example-', 'example/'}, Without Punctuation: {'example'}
# Base Token: TV, With Punctuation: {'T.V', 'T.V.'}, Without Punctuation: {'TV'}
# Base Token: society, With Punctuation: {'society/'}, Without Punctuation: {'society'}
# Base Token: differ, With Punctuation: {'differ-'}, Without Punctuation: {'differ'}
# Base Token: education, With Punctuation: {'education/'}, Without Punctuation: {'education'}
# Base Token: ready, With Punctuation: {'ready-', '-ready'}, Without Punctuation: {'ready'}
# Base Token: fact, With Punctuation: {'fact-'}, Without Punctuation: {'fact'}
# Base Token: under, With Punctuation: {'under-'}, Without Punctuation: {'under'}
# Base Token: consideration, With Punctuation: {'consideration-'}, Without Punctuation: {'consideration'}
# Base Token: 3, With Punctuation: {'3-', '-3-', '3/', '~3', '3.-'}, Without Punctuation: {'3'}
# Base Token: k, With Punctuation: {'k.'}, Without Punctuation: {'k'}
# Base Token: IG, With Punctuation: {'I.G.'}, Without Punctuation: {'IG'}
# Base Token: AV, With Punctuation: {'A.V.'}, Without Punctuation: {'AV'}
# Base Token: PURPOSE, With Punctuation: {'PURPOSE/'}, Without Punctuation: {'PURPOSE'}
# Base Token: AS, With Punctuation: {'-AS'}, Without Punctuation: {'AS'}
# Base Token: J, With Punctuation: {'J.'}, Without Punctuation: {'J'}
# Base Token: S, With Punctuation: {'S.', 'S-'}, Without Punctuation: {'S'}
# Base Token: L, With Punctuation: {'L-', 'L.'}, Without Punctuation: {'L'}
# Base Token: N, With Punctuation: {'N.'}, Without Punctuation: {'N'}
# Base Token: Y, With Punctuation: {'Y.'}, Without Punctuation: {'Y'}
# Base Token: P, With Punctuation: {'P-', 'P.'}, Without Punctuation: {'P'}
# Base Token: E, With Punctuation: {'E-', 'E.'}, Without Punctuation: {'E'}
# Base Token: K, With Punctuation: {'K-', 'K.'}, Without Punctuation: {'K'}
# Base Token: M, With Punctuation: {'M.', 'M-'}, Without Punctuation: {'M'}
# Base Token: evidence, With Punctuation: {'evidence-'}, Without Punctuation: {'evidence'}
# Base Token: value, With Punctuation: {'value/', 'value-'}, Without Punctuation: {'value'}
# Base Token: Al, With Punctuation: {'Al-'}, Without Punctuation: {'Al'}
# Base Token: Mapping, With Punctuation: {'Mapping/', 'Mapping-'}, Without Punctuation: {'Mapping'}
# Base Token: Session, With Punctuation: {'.Session'}, Without Punctuation: {'Session'}
# Base Token: early, With Punctuation: {'-early'}, Without Punctuation: {'early'}
# Base Token: stages, With Punctuation: {'stages-'}, Without Punctuation: {'stages'}
# Base Token: relevant, With Punctuation: {'relevant/'}, Without Punctuation: {'relevant'}
# Base Token: establish, With Punctuation: {'establish-'}, Without Punctuation: {'establish'}
# Base Token: Virginia, With Punctuation: {'Virginia-'}, Without Punctuation: {'Virginia'}
# Base Token: source, With Punctuation: {'source-'}, Without Punctuation: {'source'}
# Base Token: artists, With Punctuation: {'artists-'}, Without Punctuation: {'artists'}
# Base Token: session, With Punctuation: {'session-'}, Without Punctuation: {'session'}
# Base Token: stakeholder, With Punctuation: {'/stakeholder', 'stakeholder/'}, Without Punctuation: {'stakeholder'}
# Base Token: COVID, With Punctuation: {'COVID-'}, Without Punctuation: {'COVID'}
# Base Token: networking, With Punctuation: {'-networking'}, Without Punctuation: {'networking'}
# Base Token: monthly, With Punctuation: {'monthly-'}, Without Punctuation: {'monthly'}
# Base Token: before, With Punctuation: {'before-'}, Without Punctuation: {'before'}
# Base Token: Overall, With Punctuation: {'Overall/'}, Without Punctuation: {'Overall'}
# Base Token: trying, With Punctuation: {'trying-'}, Without Punctuation: {'trying'}
# Base Token: am, With Punctuation: {'a.m.'}, Without Punctuation: {'am'}
# Base Token: Coursera, With Punctuation: {'Coursera-'}, Without Punctuation: {'Coursera'}
# Base Token: job, With Punctuation: {'job/'}, Without Punctuation: {'job'}
# Base Token: includes, With Punctuation: {'includes:-'}, Without Punctuation: {'includes'}
# Base Token: department, With Punctuation: {'department-'}, Without Punctuation: {'department'}
# Base Token: asset, With Punctuation: {'asset/'}, Without Punctuation: {'asset'}
# Base Token: AR, With Punctuation: {'AR-', 'A&R'}, Without Punctuation: {'AR'}
# Base Token: departments, With Punctuation: {'departments/'}, Without Punctuation: {'departments'}
# Base Token: sign, With Punctuation: {'sign-'}, Without Punctuation: {'sign'}
# Base Token: brainstorming, With Punctuation: {'brainstorming-', '/brainstorming'}, Without Punctuation: {'brainstorming'}
# Base Token: fuel, With Punctuation: {'fuel-'}, Without Punctuation: {'fuel'}
# Base Token: concepts, With Punctuation: {'concepts/.', 'concept(s', 'concepts/'}, Without Punctuation: {'concepts'}
# Base Token: collect, With Punctuation: {'collect-'}, Without Punctuation: {'collect'}
# Base Token: issue, With Punctuation: {'issue/'}, Without Punctuation: {'issue'}
# Base Token: hypothesis, With Punctuation: {'hypothesis/', '/hypothesis', 'hypothesis-'}, Without Punctuation: {'hypothesis'}
# Base Token: below, With Punctuation: {'below-', 'below:-'}, Without Punctuation: {'below'}
# Base Token: enabled, With Punctuation: {'enable(d'}, Without Punctuation: {'enabled'}
# Base Token: THINKING, With Punctuation: {'THINKING-'}, Without Punctuation: {'THINKING'}
# Base Token: INNOVATION, With Punctuation: {'INNOVATION-'}, Without Punctuation: {'INNOVATION'}
# Base Token: narrow, With Punctuation: {'narrow-'}, Without Punctuation: {'narrow'}
# Base Token: words, With Punctuation: {'words/'}, Without Punctuation: {'words'}
# Base Token: website, With Punctuation: {'website-', 'website/'}, Without Punctuation: {'website'}
# Base Token: left, With Punctuation: {'left-'}, Without Punctuation: {'left'}
# Base Token: top, With Punctuation: {'top-'}, Without Punctuation: {'top'}
# Base Token: already, With Punctuation: {'already-'}, Without Punctuation: {'already'}
# Base Token: doing, With Punctuation: {'doing-'}, Without Punctuation: {'doing'}
# Base Token: space, With Punctuation: {'space/', 'space-'}, Without Punctuation: {'space'}
# Base Token: training, With Punctuation: {'training/'}, Without Punctuation: {'training'}
# Base Token: development, With Punctuation: {'development:-'}, Without Punctuation: {'development'}
# Base Token: step, With Punctuation: {'step-'}, Without Punctuation: {'step'}
# Base Token: prototype, With Punctuation: {'prototype-', 'prototype/'}, Without Punctuation: {'prototype'}
# Base Token: physical, With Punctuation: {'/physical'}, Without Punctuation: {'physical'}
# Base Token: play, With Punctuation: {'play-', 'play:-'}, Without Punctuation: {'play'}
# Base Token: Module, With Punctuation: {'-Module'}, Without Punctuation: {'Module'}
# Base Token: imagination, With Punctuation: {'imagination:-'}, Without Punctuation: {'imagination'}
# Base Token: pictures, With Punctuation: {'pictures-'}, Without Punctuation: {'pictures'}
# Base Token: nt, With Punctuation: {"n't"}, Without Punctuation: {'nt'}
# Base Token: She, With Punctuation: {'.She'}, Without Punctuation: {'She'}
# Base Token: maps, With Punctuation: {'maps:-', 'maps-'}, Without Punctuation: {'maps'}
# Base Token: Since, With Punctuation: {'-Since', '.Since'}, Without Punctuation: {'Since'}
# Base Token: scale, With Punctuation: {'scale-'}, Without Punctuation: {'scale'}
# Base Token: D, With Punctuation: {'D.', 'D-'}, Without Punctuation: {'D'}
# Base Token: technology, With Punctuation: {'technology-'}, Without Punctuation: {'technology'}
# Base Token: voice, With Punctuation: {'voice-'}, Without Punctuation: {'voice'}
# Base Token: over, With Punctuation: {'over-'}, Without Punctuation: {'over'}
# Base Token: At, With Punctuation: {'.At'}, Without Punctuation: {'At'}
# Base Token: challenges, With Punctuation: {'challenge(s', 'challenges-', 'challenges/'}, Without Punctuation: {'challenges'}
# Base Token: ever, With Punctuation: {'ever-'}, Without Punctuation: {'ever'}
# Base Token: upfront, With Punctuation: {'upfront-'}, Without Punctuation: {'upfront'}
# Base Token: off, With Punctuation: {'off-'}, Without Punctuation: {'off'}
# Base Token: eg, With Punctuation: {'eg-', '---e.g', 'eg.-', 'e.g.', 'e.g', '.(eg'}, Without Punctuation: {'eg'}
# ...
# Base Token: ​difficult​, With Punctuation: {'\u200bdifficult.\u200b'}, Without Punctuation: {'\u200bdifficult\u200b'}
# Base Token: ​being​, With Punctuation: {'\u200bbeing.\u200b'}, Without Punctuation: {'\u200bbeing\u200b'}
# Base Token: ​alone​, With Punctuation: {'\u200balone.\u200b'}, Without Punctuation: {'\u200balone\u200b'}
# Base Token: ​themselves​, With Punctuation: {'\u200bthemselves,\u200b'}, Without Punctuation: {'\u200bthemselves\u200b'}
# Base Token: ​quick​, With Punctuation: {'\u200bquick,\u200b'}, Without Punctuation: {'\u200bquick\u200b'}
# Base Token: ​conversation​, With Punctuation: {'\u200bconversation.\u200b'}, Without Punctuation: {'\u200bconversation\u200b'}
# Base Token: ​shame​, With Punctuation: {'\u200bshame\u200b.'}, Without Punctuation: {'\u200bshame\u200b'}
# Base Token: ​business​, With Punctuation: {'\u200bbusiness,\u200b'}, Without Punctuation: {'\u200bbusiness\u200b'}
# Base Token: 240, With Punctuation: {'2.40'}, Without Punctuation: {'240'}
# Base Token: buster, With Punctuation: {'buster-'}, Without Punctuation: {'buster'}
# Base Token: homogeneous, With Punctuation: {'homogeneous/'}, Without Punctuation: {'homogeneous'}
# Base Token: ques, With Punctuation: {'ques-'}, Without Punctuation: {'ques'}
# Base Token: criterium, With Punctuation: {'criterium/'}, Without Punctuation: {'criterium'}
# Base Token: em, With Punctuation: {"'em"}, Without Punctuation: {'em'}
# Base Token: 1800, With Punctuation: {'1,800'}, Without Punctuation: {'1800'}
# Base Token: 999, With Punctuation: {'99.9'}, Without Punctuation: {'999'}
# Base Token: Ps, With Punctuation: {'.Ps'}, Without Punctuation: {'Ps'}
# Base Token: bout, With Punctuation: {'-bout'}, Without Punctuation: {'bout'}
# Base Token: ny, With Punctuation: {'-ny'}, Without Punctuation: {'ny'}
# Base Token: ges, With Punctuation: {'-ges'}, Without Punctuation: {'ges'}
# Base Token: sk, With Punctuation: {'-sk'}, Without Punctuation: {'sk'}
# Base Token: CA, With Punctuation: {'C.A.'}, Without Punctuation: {'CA'}
# Base Token: hyderabad, With Punctuation: {'hyderabad-'}, Without Punctuation: {'hyderabad'}
# Base Token: dosent, With Punctuation: {"dosen't"}, Without Punctuation: {'dosent'}
# Base Token: ​leader​, With Punctuation: {'\u200bleader,\u200b'}, Without Punctuation: {'\u200bleader\u200b'}
# Base Token: ​agency​, With Punctuation: {'\u200bagency.\u200b', '\u200bagency,\u200b'}, Without Punctuation: {'\u200bagency\u200b'}
# Base Token: ​years​, With Punctuation: {'\u200byears,\u200b'}, Without Punctuation: {'\u200byears\u200b'}
# Base Token: ​seen​, With Punctuation: {'\u200bseen.\u200b'}, Without Punctuation: {'\u200bseen\u200b'}
# Base Token: ​ago​, With Punctuation: {'\u200bago,\u200b'}, Without Punctuation: {'\u200bago\u200b'}
# Base Token: ​exciting​, With Punctuation: {'\u200bexciting.\u200b'}, Without Punctuation: {'\u200bexciting\u200b'}
# Base Token: ​attention​, With Punctuation: {'\u200battention.\u200b'}, Without Punctuation: {'\u200battention\u200b'}
# Base Token: ​situation​, With Punctuation: {'\u200bsituation,\u200b'}, Without Punctuation: {'\u200bsituation\u200b'}
# Base Token: ​video​, With Punctuation: {'\u200b(video\u200b'}, Without Punctuation: {'\u200bvideo\u200b'}
# Base Token: ​color​, With Punctuation: {'\u200bcolor,\u200b'}, Without Punctuation: {'\u200bcolor\u200b'}
# Base Token: ​did​, With Punctuation: {'\u200bdid.\u200b'}, Without Punctuation: {'\u200bdid\u200b'}
# Base Token: ​office​, With Punctuation: {'\u200boffice.\u200b'}, Without Punctuation: {'\u200boffice\u200b'}
# Base Token: ​above​, With Punctuation: {'\u200babove,\u200b'}, Without Punctuation: {'\u200babove\u200b'}
# Base Token: ​story​, With Punctuation: {'\u200bstory,\u200b', '\u200bstory.\u200b'}, Without Punctuation: {'\u200bstory\u200b'}
# Base Token: ​too​, With Punctuation: {'\u200btoo.\u200b'}, Without Punctuation: {'\u200btoo\u200b'}
# Base Token: ​individual​, With Punctuation: {'\u200bindividual,\u200b'}, Without Punctuation: {'\u200bindividual\u200b'}
# Base Token: ​subject​, With Punctuation: {'\u200bsubject.\u200b'}, Without Punctuation: {'\u200bsubject\u200b'}
# Base Token: ​interesting​, With Punctuation: {'\u200binteresting,\u200b'}, Without Punctuation: {'\u200binteresting\u200b'}
# Base Token: innovation​, With Punctuation: {'innovation,\u200b'}, Without Punctuation: {'innovation\u200b'}
# Base Token: ​like​, With Punctuation: {'\u200blike.\u200b'}, Without Punctuation: {'\u200blike\u200b'}
# Base Token: ​situations​, With Punctuation: {'\u200bsituations.\u200b'}, Without Punctuation: {'\u200bsituations\u200b'}
# Base Token: ​complicated​, With Punctuation: {'\u200bcomplicated.\u200b'}, Without Punctuation: {'\u200bcomplicated\u200b'}
# Base Token: ​another​, With Punctuation: {'\u200banother,\u200b'}, Without Punctuation: {'\u200banother\u200b'}
# Base Token: ​result​, With Punctuation: {'\u200bresult,\u200b'}, Without Punctuation: {'\u200bresult\u200b'}
# Base Token: ​weeks​, With Punctuation: {'\u200bweeks.\u200b', '\u200bweeks,\u200b'}, Without Punctuation: {'\u200bweeks\u200b'}
# Base Token: ​well​, With Punctuation: {'\u200bwell.\u200b'}, Without Punctuation: {'\u200bwell\u200b'}
# Base Token: peo, With Punctuation: {'peo-'}, Without Punctuation: {'peo'}
# Base Token: para, With Punctuation: {'para-'}, Without Punctuation: {'para'}
# Base Token: Quantity, With Punctuation: {'-Quantity'}, Without Punctuation: {'Quantity'}
# Base Token: Routine, With Punctuation: {'-Routine'}, Without Punctuation: {'Routine'}
# Base Token: 6500, With Punctuation: {'6,500'}, Without Punctuation: {'6500'}
# Base Token: Seller, With Punctuation: {'-Seller'}, Without Punctuation: {'Seller'}
# Base Token: Style, With Punctuation: {'Style-'}, Without Punctuation: {'Style'}
# Base Token: Corp, With Punctuation: {'Corp.'}, Without Punctuation: {'Corp'}
# Base Token: Reflection​, With Punctuation: {'Reflection:\u200b'}, Without Punctuation: {'Reflection\u200b'}
# Base Token: ​prospect​, With Punctuation: {'\u200bprospect.\u200b', '\u200bprospect,\u200b'}, Without Punctuation: {'\u200bprospect\u200b'}
# Base Token: solution​, With Punctuation: {'solution\u200b.'}, Without Punctuation: {'solution\u200b'}
# Base Token: ​tools​, With Punctuation: {'\u200btools.\u200b'}, Without Punctuation: {'\u200btools\u200b'}
# Base Token: ​iDoctor​, With Punctuation: {'\u200biDoctor.\u200b', '\u200biDoctor,\u200b'}, Without Punctuation: {'\u200biDoctor\u200b'}
# Base Token: ​technology​, With Punctuation: {'\u200btechnology.\u200b'}, Without Punctuation: {'\u200btechnology\u200b'}
# Base Token: ​online​, With Punctuation: {'\u200bonline,\u200b'}, Without Punctuation: {'\u200bonline\u200b'}
# Base Token: ​doctor​, With Punctuation: {'\u200bdoctor,\u200b'}, Without Punctuation: {'\u200bdoctor\u200b'}
# Base Token: ​hour​, With Punctuation: {'\u200bhour.\u200b'}, Without Punctuation: {'\u200bhour\u200b'}
# Base Token: ​recommendations​, With Punctuation: {'\u200brecommendations.\u200b'}, Without Punctuation: {'\u200brecommendations\u200b'}
# Base Token: ​doctors​, With Punctuation: {'\u200bdoctors).\u200b'}, Without Punctuation: {'\u200bdoctors\u200b'}
# Base Token: ​easily​, With Punctuation: {'\u200beasily.\u200b'}, Without Punctuation: {'\u200beasily\u200b'}
# Base Token: territories, With Punctuation: {'territories/'}, Without Punctuation: {'territories'}
# Base Token: Mentally, With Punctuation: {'Mentally-'}, Without Punctuation: {'Mentally'}
# Base Token: wd, With Punctuation: {'w.d'}, Without Punctuation: {'wd'}
# Base Token: Leaving, With Punctuation: {'-Leaving'}, Without Punctuation: {'Leaving'}
# Base Token: moth, With Punctuation: {'moth-'}, Without Punctuation: {'moth'}
# Base Token: QAs, With Punctuation: {'Q&As'}, Without Punctuation: {'QAs'}
# Base Token: ​groups​, With Punctuation: {'\u200bgroups.\u200b'}, Without Punctuation: {'\u200bgroups\u200b'}
# Base Token: ​sessions​, With Punctuation: {'\u200bsessions.\u200b'}, Without Punctuation: {'\u200bsessions\u200b'}
# Base Token: approach​, With Punctuation: {'approach\u200b.'}, Without Punctuation: {'approach\u200b'}
# Base Token: ​faster​, With Punctuation: {'\u200bfaster,\u200b'}, Without Punctuation: {'\u200bfaster\u200b'}
# Base Token: ​Week​, With Punctuation: {'\u200b(Week\u200b'}, Without Punctuation: {'\u200bWeek\u200b'}
# Base Token: ​1​, With Punctuation: {'\u200b1)\u200b'}, Without Punctuation: {'\u200b1\u200b'}
# Base Token: ​plane​, With Punctuation: {'\u200bplane.\u200b'}, Without Punctuation: {'\u200bplane\u200b'}
# Base Token: ​session​, With Punctuation: {'\u200bsession.\u200b'}, Without Punctuation: {'\u200bsession\u200b'}
# Base Token: ​note​, With Punctuation: {'\u200bnote,\u200b'}, Without Punctuation: {'\u200bnote\u200b'}
# Base Token: ​days​, With Punctuation: {'\u200bdays.\u200b'}, Without Punctuation: {'\u200bdays\u200b'}
# Base Token: Expansion, With Punctuation: {'Expansion-'}, Without Punctuation: {'Expansion'}
# Base Token: T1, With Punctuation: {'-T1', 'T-1'}, Without Punctuation: {'T1'}
# Base Token: 7500, With Punctuation: {'7,500', '~7,500'}, Without Punctuation: {'7500'}
# Base Token: FB, With Punctuation: {'F&B'}, Without Punctuation: {'FB'}
# Base Token: Menus, With Punctuation: {'/Menus'}, Without Punctuation: {'Menus'}
# Base Token: XX, With Punctuation: {'XX%'}, Without Punctuation: {'XX'}
# Base Token: snake, With Punctuation: {'snake-'}, Without Punctuation: {'snake'}
# Base Token: Glass, With Punctuation: {'-Glass'}, Without Punctuation: {'Glass'}
# Base Token: themes​, With Punctuation: {'themes\u200b.'}, Without Punctuation: {'themes\u200b'}
# Base Token: MT, With Punctuation: {'MT-'}, Without Punctuation: {'MT'}
# Base Token: SOMA, With Punctuation: {'SOMA-'}, Without Punctuation: {'SOMA'}
# Base Token: 25000, With Punctuation: {'25.000', '25,000'}, Without Punctuation: {'25000'}
# Base Token: 1A, With Punctuation: {'1)A', '1.A'}, Without Punctuation: {'1A'}
# Base Token: NOTE, With Punctuation: {'NOTE-'}, Without Punctuation: {'NOTE'}
# Base Token: words​, With Punctuation: {'words\u200b.'}, Without Punctuation: {'words\u200b'}
# Base Token: Mapping​, With Punctuation: {'Mapping\u200b.'}, Without Punctuation: {'Mapping\u200b'}
# Base Token: inno, With Punctuation: {'inno-'}, Without Punctuation: {'inno'}
# Base Token: FF, With Punctuation: {'F&F.', 'F&F'}, Without Punctuation: {'FF'}
# Base Token: 3500, With Punctuation: {'35.00'}, Without Punctuation: {'3500'}
# Base Token: Failing, With Punctuation: {'-Failing'}, Without Punctuation: {'Failing'}
# Base Token: Police, With Punctuation: {'Police/'}, Without Punctuation: {'Police'}
# Base Token: Received, With Punctuation: {'.Received'}, Without Punctuation: {'Received'}
# Base Token: ​map, With Punctuation: {'\u200b(map'}, Without Punctuation: {'\u200bmap'}
# Base Token: Differently, With Punctuation: {'Differently-'}, Without Punctuation: {'Differently'}
# Base Token: electro, With Punctuation: {'electro-'}, Without Punctuation: {'electro'}
# Base Token: TM, With Punctuation: {'T&M'}, Without Punctuation: {'TM'}
# Base Token: AB, With Punctuation: {'A&B'}, Without Punctuation: {'AB'}
# Base Token: WEEK5, With Punctuation: {'WEEK-5'}, Without Punctuation: {'WEEK5'}
# Base Token: cocreating, With Punctuation: {'co.creating'}, Without Punctuation: {'cocreating'}
# Base Token: SCARF, With Punctuation: {'S.C.A.R.F.'}, Without Punctuation: {'SCARF'}
# Base Token: Renewal, With Punctuation: {'-Renewal'}, Without Punctuation: {'Renewal'}
# Base Token: Tracker, With Punctuation: {'Tracker-'}, Without Punctuation: {'Tracker'}
# Base Token: ideas​, With Punctuation: {'ideas\u200b.'}, Without Punctuation: {'ideas\u200b'}
# Base Token: Hope, With Punctuation: {'.Hope'}, Without Punctuation: {'Hope'}
# Base Token: PG, With Punctuation: {'P&G.', 'P&G'}, Without Punctuation: {'PG'}
# Base Token: BW, With Punctuation: {'B&W'}, Without Punctuation: {'BW'}
# Base Token: c1, With Punctuation: {'c.1'}, Without Punctuation: {'c1'}
# Base Token: c2, With Punctuation: {'c.2'}, Without Punctuation: {'c2'}
# Base Token: c3, With Punctuation: {'c.3'}, Without Punctuation: {'c3'}
# Base Token: pupae, With Punctuation: {'pupae-'}, Without Punctuation: {'pupae'}
# Base Token: gasp, With Punctuation: {'gasp-'}, Without Punctuation: {'gasp'}
# Base Token: discus, With Punctuation: {'discus-'}, Without Punctuation: {'discus'}
# Base Token: heartedly, With Punctuation: {'-heartedly'}, Without Punctuation: {'heartedly'}
# Base Token: fittings, With Punctuation: {'fittings-'}, Without Punctuation: {'fittings'}
# Base Token: 9000, With Punctuation: {'9,000'}, Without Punctuation: {'9000'}
# Base Token: FMEA, With Punctuation: {'FMEA-'}, Without Punctuation: {'FMEA'}
# Base Token: Sight, With Punctuation: {'Sight:-'}, Without Punctuation: {'Sight'}
# Base Token: edu, With Punctuation: {'edu-'}, Without Punctuation: {'edu'}
# Base Token: Weed, With Punctuation: {'-Weed-'}, Without Punctuation: {'Weed'}
# Base Token: 1100, With Punctuation: {'1:100'}, Without Punctuation: {'1100'}
# Base Token: PT, With Punctuation: {'P.T.'}, Without Punctuation: {'PT'}
# Base Token: REIT, With Punctuation: {'REIT/'}, Without Punctuation: {'REIT'}
# Base Token: ​if”​, With Punctuation: {'\u200bif”),\u200b'}, Without Punctuation: {'\u200bif”\u200b'}
# Base Token: ​deck​, With Punctuation: {'\u200bdeck,\u200b'}, Without Punctuation: {'\u200bdeck\u200b'}
# Base Token: ​criteria​, With Punctuation: {'\u200bcriteria,\u200b'}, Without Punctuation: {'\u200bcriteria\u200b'}
# Base Token: ​included​, With Punctuation: {'\u200bincluded:\u200b'}, Without Punctuation: {'\u200bincluded\u200b'}
# Base Token: brainstorming​, With Punctuation: {'brainstorming,\u200b'}, Without Punctuation: {'brainstorming\u200b'}
# Base Token: ​environment​, With Punctuation: {'\u200benvironment.\u200b'}, Without Punctuation: {'\u200benvironment\u200b'}
# Base Token: course​, With Punctuation: {'course)\u200b'}, Without Punctuation: {'course\u200b'}
# Base Token: ba, With Punctuation: {'ba-'}, Without Punctuation: {'ba'}
# Base Token: WH, With Punctuation: {'WH-'}, Without Punctuation: {'WH'}
# Base Token: MN, With Punctuation: {'M&N'}, Without Punctuation: {'MN'}
# Base Token: blah, With Punctuation: {'.blah'}, Without Punctuation: {'blah'}
# Base Token: ​price​, With Punctuation: {'\u200b(price\u200b'}, Without Punctuation: {'\u200bprice\u200b'}
# Base Token: ​associates​, With Punctuation: {'\u200bassociates,\u200b'}, Without Punctuation: {'\u200bassociates\u200b'}
# Base Token: ​protection​, With Punctuation: {'\u200bprotection.\u200b', '\u200bprotection)\u200b', '\u200bprotection,\u200b'}, Without Punctuation: {'\u200bprotection\u200b'}
# Base Token: ​launch​, With Punctuation: {'\u200blaunch,\u200b'}, Without Punctuation: {'\u200blaunch\u200b'}
# Base Token: ​risk​, With Punctuation: {'\u200brisk,\u200b'}, Without Punctuation: {'\u200brisk\u200b'}
# Base Token: customers​, With Punctuation: {'customers.\u200b', 'customers,\u200b'}, Without Punctuation: {'customers\u200b'}
# Base Token: ​lacking​, With Punctuation: {'\u200blacking.\u200b'}, Without Punctuation: {'\u200blacking\u200b'}
# Base Token: ser, With Punctuation: {'ser-'}, Without Punctuation: {'ser'}
# Base Token: AIESEC, With Punctuation: {'AIESEC-'}, Without Punctuation: {'AIESEC'}
# Base Token: 69, With Punctuation: {'6/9'}, Without Punctuation: {'69'}
# Base Token: rig, With Punctuation: {'rig/'}, Without Punctuation: {'rig'}
# Base Token: 1Design, With Punctuation: {'1.Design'}, Without Punctuation: {'1Design'}
# Base Token: fu, With Punctuation: {'fu-'}, Without Punctuation: {'fu'}
# Base Token: MI, With Punctuation: {'MI/'}, Without Punctuation: {'MI'}
# Base Token: week1, With Punctuation: {'week-1'}, Without Punctuation: {'week1'}
# Base Token: Mildly, With Punctuation: {'Mildly-'}, Without Punctuation: {'Mildly'}
# Base Token: ​gaps​, With Punctuation: {'\u200bgaps.\u200b'}, Without Punctuation: {'\u200bgaps\u200b'}
# Base Token: ​filled​, With Punctuation: {'\u200bfilled.\u200b'}, Without Punctuation: {'\u200bfilled\u200b'}
# Base Token: ​Customer​, With Punctuation: {'\u200bCustomer.\u200b'}, Without Punctuation: {'\u200bCustomer\u200b'}
# Base Token: denomination, With Punctuation: {'denomination/'}, Without Punctuation: {'denomination'}

# %% [markdown]
# ### Based on the cell results above it seems like there exists token with punctuation versions
#
# - Considering standardizing the tokens after a more basic EDA of the rest of the features

# %% [markdown]
# <h3> Label Distribution

# %%
all_labels = [label for sublist in df['labels'] for label in sublist]
label_freq = nltk.FreqDist(all_labels)
plt.xticks(rotation=90)
plt.bar(label_freq.keys(), label_freq.values())
plt.xlabel('Labels')
plt.ylabel('Frequency')
plt.title('Distribution of Labels')
plt.show()

# %%
all_labels = [label for sublist in df['labels'] for label in sublist if label != "O"]

#  Count the frequencies of the worded labels
label_frequencies = Counter(all_labels)

#  Print the frequency of each label
for label, count in label_frequencies.items():
    print(f"{label}: {count}")
# Out:
# B-NAME_STUDENT: 1365
# I-NAME_STUDENT: 1096
# B-URL_PERSONAL: 110
# B-EMAIL: 39
# B-ID_NUM: 78
# I-URL_PERSONAL: 1
# B-USERNAME: 6
# B-PHONE_NUM: 6
# I-PHONE_NUM: 15
# B-STREET_ADDRESS: 2
# I-STREET_ADDRESS: 20
# I-ID_NUM: 1

# %%
### Checking out some rows with these labels present 
labels_of_interest = ["B-EMAIL", "B-ID_NUM"]

for label in labels_of_interest:
    # Use a boolean mask to filter rows where our label of interest is found
    mask = df['labels'].apply(lambda x: label in x)
    
    # Display the filtered rows for this label
    display(df[mask].head())  # Using .head() to display a few rows, adjust as needed
# Out:
#      document                                          full_text  \
# 24        379  COURSERA – University of Virginia, Darden Scho...
# 86       2769  Design Thinking for Innovation\n\nby Universit...
# 134      3709  , Vol.7, No.5, May 2009\n\nE-ISSN: 2321-9637\n...
# 171      4227  Mohamed Smith (agood@gmail.com)\n\nVisualizati...
# 185      4381  WRITING CENTRE  Level 3 East, Hub Central  Nor...
#
#                                                 tokens  \
# 24   [COURSERA, –, University, of, Virginia, ,, Dar...
# 86   [Design, Thinking, for, Innovation, \n\n, by, ...
# 134  [,, Vol.7, ,, No.5, ,, May, 2009, \n\n, E, -, ...
# 171  [Mohamed, Smith, (, agood@gmail.com, ), \n\n, ...
# 185  [WRITING, CENTRE,  , Level, 3, East, ,, Hub, C...
#
#                                    trailing_whitespace  \
# 24   [True, True, True, True, False, True, True, Tr...
# 86   [True, True, True, False, False, True, True, T...
# 134  [True, False, True, False, True, True, False, ...
# 171  [True, True, False, False, False, False, False...
# 185  [True, True, False, True, True, False, True, T...
#
#                                                 labels  text_length  \
# 24   [O, O, O, O, O, O, O, O, O, O, O, O, O, O, O, ...         4244
# 86   [O, O, O, O, O, O, O, O, O, O, O, O, O, O, O, ...         3084
# 134  [O, O, O, O, O, O, O, O, O, O, O, O, O, O, O, ...        12098
# 171  [B-NAME_STUDENT, I-NAME_STUDENT, O, B-EMAIL, O...         4118
# 185  [O, O, O, O, O, O, O, O, O, O, O, O, O, O, O, ...         6147
#
#      token_count
# 24           766
# 86           623
# 134         2456
# 171          803
# 185         1222
#      document                                          full_text  \
# 29        609  Date:14-09-2021\n\nNEWS PAPER\n\nProject: News...
# 99       2926  NAME: Ignacia Hernandez   Roll No. : 932353568...
# 124      3565  Project:  Experiment sheet (5W+H)\n\nInterview...
# 213      4717  STORY TELLING\n\nPIN NO. :163133980712   NAME ...
# 231      4913  DESIGN THINKING\n\nEXPERIMENT – 2\n\nName: Niz...
#
#                                                 tokens  \
# 29   [Date:14, -, 09, -, 2021, \n\n, NEWS, PAPER, \...
# 99   [NAME, :, Ignacia, Hernandez,   , Roll, No, .,...
# 124  [Project, :,  , Experiment, sheet, (, 5W+H, ),...
# 213  [STORY, TELLING, \n\n, PIN, NO, ., :, 16313398...
# 231  [DESIGN, THINKING, \n\n, EXPERIMENT, –, 2, \n\...
#
#                                    trailing_whitespace  \
# 29   [False, False, False, False, False, False, Tru...
# 99   [False, True, True, True, False, True, False, ...
# 124  [False, True, False, True, True, False, False,...
# 213  [True, False, False, True, False, True, False,...
# 231  [True, False, False, True, True, False, False,...
#
#                                                 labels  text_length  \
# 29   [O, O, O, O, O, O, O, O, O, O, O, O, O, O, O, ...         4195
# 99   [O, O, B-NAME_STUDENT, I-NAME_STUDENT, O, O, O...         1774
# 124  [O, O, O, O, O, O, O, O, O, O, O, O, B-NAME_ST...         1756
# 213  [O, O, O, O, O, O, O, B-ID_NUM, O, O, O, B-NAM...         1946
# 231  [O, O, O, O, O, O, O, O, O, B-NAME_STUDENT, I-...         2471
#
#      token_count
# 29           915
# 99           429
# 124          428
# 213          443
# 231          605

# %% [markdown]
# <h4> Wordcloud for Text

# %%
wordcloud = WordCloud(width=800, height=400, background_color ='white').generate(' '.join(all_words))
plt.figure(figsize = (8, 8), facecolor = None) 
plt.imshow(wordcloud) 
plt.axis("off") 
plt.tight_layout(pad = 0) 
plt.show()

# %% [markdown]
# ### First Attempt : For the first attempt, we will not be adding addtional datasets. We'll try and optimize the exisiting features through EDA and applicable transformations before deciding on the model

# %% [markdown]
# ### This alligns with a Named Entity Recognition (NER) task

# %% [markdown]
# #### For label observations we know that the ratio of '0' in the label lists are way higher than the worded labels. We'll print out some of the document rows with the worded labels, which will help get an overview of what PII exists in the text of a document row

# %%
def print_labels_with_values(df):
    for index, row in df.iterrows():
        print(f"Document number {row['document']}:")
        
        # Zip together the tokens and labels for parallel iteration
        paired = list(zip(row['tokens'], row['labels']))
        
        # Filter out pairs where label is 'O', and print remaining tokens with their labels
        for token, label in paired:
            if label != 'O':
                print(f"\tToken: {token}, Label: {label}")
        print("-" * 50)  # Separator for readability

print_labels_with_values(df[300:350])
# Out:
# Document number 5716:
# 	Token: meyermichelle, Label: B-USERNAME
# --------------------------------------------------
# Document number 5717:
# 	Token: Natalya, Label: B-NAME_STUDENT
# 	Token: Kotov, Label: I-NAME_STUDENT
# --------------------------------------------------
# Document number 5731:
# 	Token: Abdul, Label: B-NAME_STUDENT
# 	Token: Rohim, Label: I-NAME_STUDENT
# 	Token: Abdul, Label: B-NAME_STUDENT
# 	Token: Rohim, Label: I-NAME_STUDENT
# --------------------------------------------------
# Document number 5736:
# 	Token: Pietro, Label: B-NAME_STUDENT
# 	Token: Gabrielli, Label: I-NAME_STUDENT
# --------------------------------------------------
# Document number 5738:
# 	Token: Kara, Label: B-NAME_STUDENT
# 	Token: Deniz, Label: I-NAME_STUDENT
# --------------------------------------------------
# Document number 5748:
# 	Token: Mohamed, Label: B-NAME_STUDENT
# 	Token: Kamal, Label: I-NAME_STUDENT
# 	Token: Mohamed, Label: B-NAME_STUDENT
# 	Token: Kamal, Label: I-NAME_STUDENT
# --------------------------------------------------
# Document number 5775:
# 	Token: Saadiah, Label: B-NAME_STUDENT
# 	Token: Jie, Label: I-NAME_STUDENT
# --------------------------------------------------
# Document number 5780:
# 	Token: Giuseppe, Label: B-NAME_STUDENT
# 	Token: Longo, Label: I-NAME_STUDENT
# 	Token: Giuseppe, Label: B-NAME_STUDENT
# 	Token: Longo, Label: I-NAME_STUDENT
# --------------------------------------------------
# Document number 5796:
# 	Token: Dharmendra, Label: B-NAME_STUDENT
# 	Token: Dharmendra, Label: I-NAME_STUDENT
# 	Token: Dharmendra, Label: B-NAME_STUDENT
# 	Token: Dharmendra, Label: I-NAME_STUDENT
# 	Token: 696135165639, Label: B-ID_NUM
# 	Token: Vw.:403489591437, Label: B-ID_NUM
# --------------------------------------------------
# Document number 5811:
# 	Token: Federica, Label: B-NAME_STUDENT
# 	Token: Federica, Label: B-NAME_STUDENT
# --------------------------------------------------
# Document number 5816:
# 	Token: Jo, Label: B-NAME_STUDENT
# 	Token: Kelly, Label: I-NAME_STUDENT
# --------------------------------------------------
# Document number 5830:
# 	Token: Ivica, Label: B-NAME_STUDENT
# 	Token: Marija, Label: I-NAME_STUDENT
# --------------------------------------------------
# Document number 5840:
# 	Token: Yaser, Label: B-NAME_STUDENT
# 	Token: Mostafa, Label: I-NAME_STUDENT
# --------------------------------------------------
# Document number 5855:
# 	Token: May, Label: B-NAME_STUDENT
# 	Token: Sutton, Label: I-NAME_STUDENT
# --------------------------------------------------
# Document number 5874:
# 	Token: Neia, Label: B-NAME_STUDENT
# 	Token: Rodrigues, Label: I-NAME_STUDENT
# --------------------------------------------------
# Document number 5896:
# 	Token: Donya, Label: B-NAME_STUDENT
# 	Token: Donya, Label: I-NAME_STUDENT
# --------------------------------------------------
# Document number 5902:
# 	Token: Sam, Label: B-NAME_STUDENT
# 	Token: Chan, Label: I-NAME_STUDENT
# 	Token: Karen, Label: B-NAME_STUDENT
# --------------------------------------------------
# Document number 5906:
# 	Token: Cristina, Label: B-NAME_STUDENT
# 	Token: Valerio, Label: I-NAME_STUDENT
# 	Token: Cristina, Label: B-NAME_STUDENT
# 	Token: Valerio, Label: I-NAME_STUDENT
# --------------------------------------------------
# Document number 5910:
# 	Token: Sara, Label: B-NAME_STUDENT
# 	Token: Garcia, Label: I-NAME_STUDENT
# --------------------------------------------------
# Document number 5922:
# 	Token: Leonardo, Label: B-NAME_STUDENT
# 	Token: Giles, Label: I-NAME_STUDENT
# --------------------------------------------------
# Document number 5923:
# 	Token: https://jones-hernandez.com/main/tag/listindex.htm, Label: B-URL_PERSONAL
# 	Token: https://jones-hernandez.com/main/tag/listindex.htm, Label: B-URL_PERSONAL
# --------------------------------------------------
# Document number 5935:
# 	Token: Mohamad, Label: B-NAME_STUDENT
# --------------------------------------------------
# Document number 5944:
# 	Token: Margarita, Label: B-NAME_STUDENT
# 	Token: Gould, Label: I-NAME_STUDENT
# --------------------------------------------------
# Document number 5952:
# 	Token: Yareli, Label: B-NAME_STUDENT
# 	Token: Thomas, Label: I-NAME_STUDENT
# --------------------------------------------------
# Document number 5964:
# 	Token: Karla, Label: B-NAME_STUDENT
# --------------------------------------------------
# Document number 6002:
# 	Token: Uriel, Label: B-NAME_STUDENT
# 	Token: Romero, Label: I-NAME_STUDENT
# --------------------------------------------------
# Document number 6007:
# 	Token: https://www.youtube.com/watch?v=2sOzgGAeiQV, Label: B-URL_PERSONAL
# --------------------------------------------------
# Document number 6023:
# 	Token: Sarah, Label: B-NAME_STUDENT
# 	Token: Calixto, Label: I-NAME_STUDENT
# 	Token: Sarah, Label: B-NAME_STUDENT
# 	Token: Calixto, Label: I-NAME_STUDENT
# --------------------------------------------------
# Document number 6027:
# 	Token: Enrico, Label: B-NAME_STUDENT
# 	Token: Laterza, Label: I-NAME_STUDENT
# --------------------------------------------------
# Document number 6049:
# 	Token: Yessica, Label: B-NAME_STUDENT
# 	Token: Lopes, Label: I-NAME_STUDENT
# --------------------------------------------------
# Document number 6057:
# 	Token: Lerato, Label: B-NAME_STUDENT
# 	Token: Salem, Label: I-NAME_STUDENT
# --------------------------------------------------
# Document number 6064:
# 	Token: Silvia, Label: B-NAME_STUDENT
# --------------------------------------------------
# Document number 6074:
# 	Token: Abdul, Label: B-NAME_STUDENT
# 	Token: Nasar, Label: I-NAME_STUDENT
# --------------------------------------------------
# Document number 6085:
# 	Token: Siew, Label: B-NAME_STUDENT
# 	Token: Santamaria, Label: I-NAME_STUDENT
# --------------------------------------------------
# Document number 6088:
# 	Token: Julia, Label: B-NAME_STUDENT
# 	Token: Bock, Label: I-NAME_STUDENT
# --------------------------------------------------
# Document number 6095:
# 	Token: Angelo, Label: B-NAME_STUDENT
# 	Token: Martello, Label: I-NAME_STUDENT
# --------------------------------------------------
# Document number 6101:
# 	Token: Martina, Label: B-NAME_STUDENT
# 	Token: Chong, Label: I-NAME_STUDENT
# --------------------------------------------------
# Document number 6117:
# 	Token: Hari, Label: B-NAME_STUDENT
# 	Token: Sharma, Label: I-NAME_STUDENT
# --------------------------------------------------
# Document number 6121:
# 	Token: Thai, Label: B-NAME_STUDENT
# 	Token: Tamang, Label: I-NAME_STUDENT
# --------------------------------------------------
# Document number 6124:
# 	Token: Victoria, Label: B-NAME_STUDENT
# 	Token: Horton, Label: I-NAME_STUDENT
# --------------------------------------------------
# Document number 6133:
# 	Token: Mahammad, Label: B-NAME_STUDENT
# 	Token: Khan, Label: I-NAME_STUDENT
# --------------------------------------------------
# Document number 6139:
# 	Token: Stephanie, Label: B-NAME_STUDENT
# 	Token: Johnstone, Label: I-NAME_STUDENT
# --------------------------------------------------
# Document number 6148:
# 	Token: Christian, Label: B-NAME_STUDENT
# --------------------------------------------------
# Document number 6155:
# 	Token: Khairul, Label: B-NAME_STUDENT
# 	Token: Rahman, Label: I-NAME_STUDENT
# --------------------------------------------------
# Document number 6169:
# 	Token: Sagar, Label: B-NAME_STUDENT
# 	Token: Sanchez, Label: I-NAME_STUDENT
# --------------------------------------------------
# Document number 6171:
# 	Token: Alexandra, Label: B-NAME_STUDENT
# 	Token: Serafini, Label: I-NAME_STUDENT
# --------------------------------------------------
# Document number 6174:
# 	Token: Phillip, Label: B-NAME_STUDENT
# 	Token: Santillan, Label: I-NAME_STUDENT
# --------------------------------------------------
# Document number 6187:
# 	Token: Gino, Label: B-NAME_STUDENT
# 	Token: Schiavo, Label: I-NAME_STUDENT
# --------------------------------------------------
# Document number 6194:
# 	Token: http://www.miller.org/search/tags/tagsearch.php, Label: B-URL_PERSONAL
# --------------------------------------------------
# Document number 6220:
# 	Token: Alison, Label: B-NAME_STUDENT
# --------------------------------------------------
